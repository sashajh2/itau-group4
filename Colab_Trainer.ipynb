# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
### !git clone https://github.com/your-username/itau-group2.git
# !git clone https://github.com/sashajh2/itau-group4/
# Out:
# fatal: destination path 'itau-group2' already exists and is not an empty directory.

# %%
# !pwd
# Out:
# /content/itau-group2

# %%
# !git pull origin
# Out:
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 8 (delta 6), reused 8 (delta 6), pack-reused 0 (from 0)
# Unpacking objects: 100% (8/8), 618 bytes | 618.00 KiB/s, done.
# From https://github.com/sashajh2/itau-group2
#    e83d19e..30a7376  sasha-infonce -> origin/sasha-infonce
# Updating e83d19e..30a7376
# Fast-forward
#  model_utils/loss/infonce_loss.py       |  2 +-
#  model_utils/models/learning/infonce.py | 10 +++++-----
#  2 files changed, 6 insertions(+), 6 deletions(-)

# %%
# !git checkout sasha/training-refactor
# Out:
# Branch 'sasha-infonce' set up to track remote branch 'sasha-infonce' from 'origin'.
# Switched to a new branch 'sasha-infonce'

# %%
# !git pull origin sasha/training-refactor
# Out:
# From https://github.com/sashajh2/itau-group2
#  * branch            sasha-infonce -> FETCH_HEAD
# Already up to date.

# %%
# !git status
# Out:
# On branch sean-tuning
# Your branch is up to date with 'origin/sean-tuning'.
#
# nothing to commit, working tree clean

# %%
#ensure this is /content/itau-group2
# !pwd
# Out:
# /content/itau-group2

# %%
# %pip install -r requirements.txt -c constraints.txt
# Out:
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# ...
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl (755.6 MB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu118
#     Uninstalling torch-2.6.0+cu118:
#       Successfully uninstalled torch-2.6.0+cu118
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
# ...

# %%
# !PYTHONPATH=$PYTHONPATH:/content/itau-group2 \
python scripts/main.py \
 --mode optuna \
 --test_filepath "/content/itau-group2/data/processed/test_pairs_ref_nocom.parquet" \
 --training_filepath "/content/itau-group2/data/processed/train_infonce_hard_70k.parquet" \
 --easy_filepath "/content/itau-group2/data/processed/train_infonce_easy_70k.parquet" \
 --medium_filepath "/content/itau-group2/data/processed/train_infonce_medium_70k.parquet" \
 --validate_filepath "/content/itau-group2/data/processed/test_pairs_10k.parquet" \
 --model_type infonce \
 --loss_type cosine \
 --epochs 10 \
 --n_trials 13 \
 --batch_size 32 \
 --backbone siglip
# Out:
# Model type: siglip, Embedding dimension: 768
# Model type: siglip, Embedding dimension: 768
# Model type: siglip, Embedding dimension: 768
# Starting Optuna optimization for siglip model
# Mode: infonce, Loss: cosine
# Sampler: tpe, Pruner: median
# Will run 13 trials
#
# ...
# Starting Trial 1
# ...
# Testing parameters: LR: 0.000056, Batch: 64, Layer: 512, Opt: adam, WD: 0.000016, Temp: 0.5399
# InfoNCEDataset: Consistent negative count detected. All samples have 9 negatives.
# InfoNCEDataset: Consistent negative count detected. All samples have 5 negatives.
# InfoNCEDataset: Consistent negative count detected. All samples have 9 negatives.
# USING SUPCON EMBEDDING EXTRACTOR
# [DEBUG] Using fixed learning rate: 0.000056
# USING SUPCON EMBEDDING EXTRACTOR
# [DEBUG][Manual Curriculum] Epoch 1: Using EASY dataset
# Step 0 complete out of 1090 | LR: 0.000056
# Step 100 complete out of 1090 | LR: 0.000056
# Step 200 complete out of 1090 | LR: 0.000056
# Step 300 complete out of 1090 | LR: 0.000056
# ...

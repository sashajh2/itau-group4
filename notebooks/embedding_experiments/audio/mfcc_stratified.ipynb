# %%
# !git clone https://github.com/sashajh2/itau-group4/
# Out:
# Cloning into 'itau-group4'...
# remote: Enumerating objects: 214, done.
# remote: Counting objects: 100% (214/214), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 214 (delta 82), reused 186 (delta 54), pack-reused 0 (from 0)
# Receiving objects: 100% (214/214), 17.63 MiB | 36.61 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
# %cd itau-group4
# Out:
# /content/itau-group4

# %%
# !git pull origin
# Out:
# Already up to date.

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
#ensure this is /content/itau-group4
# !pwd
# Out:
# /content/itau-group4

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: librosa==0.11.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (3.10.0)
# Collecting moviepy==2.2.1 (from -r requirements.txt (line 3))
#   Downloading moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Collecting openl3==0.4.2 (from -r requirements.txt (line 5))
#   Downloading openl3-0.4.2.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pandas==2.3.0 (from -r requirements.txt (line 6))
#   Downloading pandas-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: tensorflow_hub==0.16.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (0.16.1)
# Collecting torch==2.7.1 (from -r requirements.txt (line 9))
#   Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting transformers==4.53.1 (from -r requirements.txt (line 10))
#   Downloading transformers-4.53.1-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (1.15.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa==0.11.0->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy==2.2.1->-r requirements.txt (line 3)) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy==2.2.1->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy==2.2.1->-r requirements.txt (line 3)) (0.1.12)
# Collecting python-dotenv>=0.10 (from moviepy==2.2.1->-r requirements.txt (line 3))
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pillow<12.0,>=9.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy==2.2.1->-r requirements.txt (line 3)) (11.2.1)
# Requirement already satisfied: tensorflow>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from openl3==0.4.2->-r requirements.txt (line 5)) (2.18.0)
# Collecting kapre>=0.3.5 (from openl3==0.4.2->-r requirements.txt (line 5))
#   Downloading kapre-0.3.7.tar.gz (26 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting resampy<0.3.0,>=0.2.1 (from openl3==0.4.2->-r requirements.txt (line 5))
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h5py>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from openl3==0.4.2->-r requirements.txt (line 5)) (3.14.0)
# Requirement already satisfied: scikit-image>=0.14.3 in /usr/local/lib/python3.11/dist-packages (from openl3==0.4.2->-r requirements.txt (line 5)) (0.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.3.0->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.3.0->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas==2.3.0->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow_hub==0.16.1->-r requirements.txt (line 8)) (5.29.5)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow_hub==0.16.1->-r requirements.txt (line 8)) (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.7.1->-r requirements.txt (line 9)) (3.18.0)
# Collecting sympy>=1.13.3 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.7.1->-r requirements.txt (line 9)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.7.1->-r requirements.txt (line 9)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.7.1->-r requirements.txt (line 9)) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch==2.7.1->-r requirements.txt (line 9))
#   Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.1->-r requirements.txt (line 10)) (0.33.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.1->-r requirements.txt (line 10)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.1->-r requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.1->-r requirements.txt (line 10)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.1->-r requirements.txt (line 10)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.1->-r requirements.txt (line 10)) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.1->-r requirements.txt (line 10)) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.1->-r requirements.txt (line 10)) (4.67.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.3.1->torch==2.7.1->-r requirements.txt (line 9)) (75.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 2)) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 2)) (3.2.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.1->-r requirements.txt (line 10)) (1.1.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa==0.11.0->-r requirements.txt (line 1)) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa==0.11.0->-r requirements.txt (line 1)) (4.3.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas==2.3.0->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.1->-r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.1->-r requirements.txt (line 10)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.1->-r requirements.txt (line 10)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.1->-r requirements.txt (line 10)) (2025.6.15)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.14.3->openl3==0.4.2->-r requirements.txt (line 5)) (2025.6.11)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa==0.11.0->-r requirements.txt (line 1)) (1.17.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch==2.7.1->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (3.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (3.8.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (0.37.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.7.1->-r requirements.txt (line 9)) (3.0.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (0.45.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa==0.11.0->-r requirements.txt (line 1)) (2.22)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.0.0->openl3==0.4.2->-r requirements.txt (line 5)) (0.1.2)
# Downloading moviepy-2.2.1-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 12.1 MB/s eta 0:00:00
# Downloading pandas-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 121.0 MB/s eta 0:00:00
# Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 1.7 MB/s eta 0:00:00
# Downloading transformers-4.53.1-py3-none-any.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 87.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 100.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 81.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 57.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 15.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 10.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 45.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 7.9 MB/s eta 0:00:00
# Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 13.6 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 56.3 MB/s eta 0:00:00
# Building wheels for collected packages: openl3, kapre, resampy
#   Building wheel for openl3 (setup.py) ... done
#   Created wheel for openl3: filename=openl3-0.4.2-py2.py3-none-any.whl size=249327030 sha256=98972a32d520d168f1a206f20d6576a77926b3d1f3eb5b1a66795793e030e011
#   Stored in directory: /root/.cache/pip/wheels/35/e9/4c/b1e39385b21f2b4d70c01b8793ecc921d69f167cc772868abe
#   Building wheel for kapre (pyproject.toml) ... done
#   Created wheel for kapre: filename=kapre-0.3.7-py3-none-any.whl size=29642 sha256=a49bb981cba6024d829989fd388022009b5fb557c0140e097d9403433a16570c
#   Stored in directory: /root/.cache/pip/wheels/d2/17/ce/09b7d799a7c8b463b0a1657941331e0f10112864ff78d28f87
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320705 sha256=399806860e65c8a3544925df776a6aff78cd5a4e6425899c300efd7c80ead8ba
#   Stored in directory: /root/.cache/pip/wheels/0f/df/63/a2209e98c9b8599049252b409794538bff2aa0d37b5e71fab6
# Successfully built openl3 kapre resampy
# Installing collected packages: nvidia-cusparselt-cu12, triton, sympy, python-dotenv, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, resampy, pandas, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, moviepy, nvidia-cusolver-cu12, transformers, torch, kapre, openl3
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.6.2
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: moviepy
#     Found existing installation: moviepy 1.0.3
#     Uninstalling moviepy-1.0.3:
#       Successfully uninstalled moviepy-1.0.3
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.53.0
#     Uninstalling transformers-4.53.0:
#       Successfully uninstalled transformers-4.53.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.0 which is incompatible.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.1 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.7.1 which is incompatible.
# cudf-cu12 25.2.1 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.0 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.7.1 which is incompatible.
# dask-cudf-cu12 25.2.2 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.0 which is incompatible.
# Successfully installed kapre-0.3.7 moviepy-2.2.1 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 openl3-0.4.2 pandas-2.3.0 python-dotenv-1.1.1 resampy-0.2.2 sympy-1.14.0 torch-2.7.1 transformers-4.53.1 triton-3.3.1

# %%
# !PYTHONPATH=$PYTHONPATH:/content/itau-group4 \
python evaluation/embeddings/embedding_eval.py \
  --embeddings embeddings/audio/mfcc/mfcc_embeddings.npy \
  --labels labels/audio/mfcc/mfcc_labels.pkl \
  --metadata data/exploratory-datasets/audio_dataset_with_perturbations.pkl \
  --stratify_mode audio \
  --output mfcc_stratified_results.pkl
# Out:
# Loading embeddings from .npy file: embeddings/audio/mfcc/mfcc_embeddings.npy
# Stratifying by audio perturbation columns: ['reverberation', 'room_impulse', 'doppler', 'interference', 'compression_artifacts', 'clipping', 'time_stretch', 'pitch_loudness', 'frequency_filter', 'white_noise', 'ambient_noise']
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Fold 1 results: {'roc_auc': np.float64(0.8503937007874015), 'best_thresh_fpr': np.float64(0.85), 'fnr_at_1pfpr': np.float64(0.8571428571428571), 'best_cm_fpr': [[126, 1], [72, 12]], 'best_thresh_acc': np.float64(0.55), 'max_acc': 0.8056872037914692, 'best_cm_acc': [[106, 21], [20, 64]]}
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Fold 2 results: {'roc_auc': np.float64(0.7294713160854893), 'best_thresh_fpr': np.float64(0.9500000000000001), 'fnr_at_1pfpr': np.float64(0.9047619047619048), 'best_cm_fpr': [[126, 1], [76, 8]], 'best_thresh_acc': np.float64(0.6), 'max_acc': 0.7061611374407583, 'best_cm_acc': [[98, 29], [33, 51]]}
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Fold 3 results: {'roc_auc': np.float64(0.7906824146981627), 'best_thresh_fpr': np.float64(0.87), 'fnr_at_1pfpr': np.float64(0.9285714285714286), 'best_cm_fpr': [[126, 1], [78, 6]], 'best_thresh_acc': np.float64(0.54), 'max_acc': 0.7393364928909952, 'best_cm_acc': [[97, 30], [25, 59]]}
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Fold 4 results: {'roc_auc': np.float64(0.7893937956550612), 'best_thresh_fpr': np.float64(0.8300000000000001), 'fnr_at_1pfpr': np.float64(0.8192771084337349), 'best_cm_fpr': [[126, 1], [68, 15]], 'best_thresh_acc': np.float64(0.54), 'max_acc': 0.7476190476190476, 'best_cm_acc': [[100, 27], [26, 57]]}
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Fold 5 results: {'roc_auc': np.float64(0.8064699743857319), 'best_thresh_fpr': np.float64(0.9500000000000001), 'fnr_at_1pfpr': np.float64(0.9879518072289156), 'best_cm_fpr': [[126, 1], [82, 1]], 'best_thresh_acc': np.float64(0.54), 'max_acc': 0.780952380952381, 'best_cm_acc': [[102, 25], [21, 62]]}
# Results saved to mfcc_stratified_results.pkl

# %%
import pandas as pd
results = pd.read_pickle('mfcc_stratified_results.pkl')

# %%
print(results)
# Out:
# [{'global': {'roc_auc': np.float64(0.8503937007874015), 'best_thresh_fpr': np.float64(0.85), 'fnr_at_1pfpr': np.float64(0.8571428571428571), 'best_cm_fpr': [[126, 1], [72, 12]], 'best_thresh_acc': np.float64(0.55), 'max_acc': 0.8056872037914692, 'best_cm_acc': [[106, 21], [20, 64]]}, 'stratified': {('reverberation', False): {'roc_auc': np.float64(0.8575683437932135), 'best_thresh_fpr': np.float64(0.85), 'fnr_at_1pfpr': np.float64(0.8607594936708861), 'best_cm_fpr': [[118, 1], [68, 11]], 'best_thresh_acc': np.float64(0.55), 'max_acc': 0.8232323232323232, 'best_cm_acc': [[101, 18], [17, 62]]}, ('reverberation', True): {'roc_auc': np.float64(0.725), 'best_thresh_fpr': np.float64(0.72), 'fnr_at_1pfpr': np.float64(0.8), 'best_cm_fpr': [[8, 0], [4, 1]], 'best_thresh_acc': np.float64(0.17), 'max_acc': 0.6923076923076923, 'best_cm_acc': [[4, 4], [0, 5]]}, ('room_impulse', False): {'roc_auc': np.float64(0.8497460918052375), 'best_thresh_fpr': np.float64(0.85), 'fnr_at_1pfpr': np.float64(0.8554216867469879), 'best_cm_fpr': [[120, 1], [71, 12]], 'best_thresh_acc': np.float64(0.55), 'max_acc': 0.803921568627451, 'best_cm_acc': [[101, 20], [20, 63]]}, ('room_impulse', True): {'roc_auc': np.float64(1.0), 'best_thresh_fpr': np.float64(0.72), 'fnr_at_1pfpr': np.float64(0.0), 'best_cm_fpr': [[6, 0], [0, 1]], 'best_thresh_acc': np.float64(0.72), 'max_acc': 1.0, 'best_cm_acc': [[6, 0], [0, 1]]}, ('doppler', False): {'roc_auc': np.float64(0.8597931549205672), 'best_thresh_fpr': np.float64(0.8400000000000001), 'fnr_at_1pfpr': np.float64(0.8072289156626506), 'best_cm_fpr': [[112, 1], [67, 16]], 'best_thresh_acc': np.float64(0.49), 'max_acc': 0.8214285714285714, 'best_cm_acc': [[94, 19], [16, 67]]}, ('doppler', True): {'roc_auc': np.float64(0.4285714285714286), 'best_thresh_fpr': np.float64(0.85), 'fnr_at_1pfpr': np.float64(1.0), 'best_cm_fpr': [[14, 0], [1, 0]], 'best_thresh_acc': np.float64(0.85), 'max_acc': 0.9333333333333333, 'best_cm_acc': [[14, 0], [1, 0]]}, ('interference', False): {'roc_auc': np.float64(0.8584504044274158), 'best_thresh_fpr': np.float64(0.85), 'fnr_at_1pfpr': np.float64(0.8518518518518519), 'best_cm_fpr': [[115, 1], [69, 12]], 'best_thresh_acc': np.float64(0.55), 'max_acc': 0.8071065989847716, 'best_cm_acc': [[95, 21], [17, 64]]}, ('interference', True): {'roc_auc': np.float64(0.4848484848484848), 'best_thresh_fpr': np.float64(0.29000000000000004), 'fnr_at_1pfpr': np.float64(0.6666666666666666), 'best_cm_fpr': [[11, 0], [2, 1]], 'best_thresh_acc': np.float64(0.29000000000000004), 'max_acc': 0.8571428571428571, 'best_cm_acc': [[11, 0], [2, 1]]}, ('compression_artifacts', False): {'roc_auc': np.float64(0.8430645659561321), 'best_thresh_fpr': np.float64(0.85), 'fnr_at_1pfpr': np.float64(0.8554216867469879), 'best_cm_fpr': [[116, 1], [71, 12]], 'best_thresh_acc': np.float64(0.55), 'max_acc': 0.8, 'best_cm_acc': [[96, 21], [19, 64]]}, ('compression_artifacts', True): {'roc_auc': np.float64(0.9), 'best_thresh_fpr': np.float64(0.47000000000000003), 'fnr_at_1pfpr': np.float64(1.0), 'best_cm_fpr': [[10, 0], [1, 0]], 'best_thresh_acc': np.float64(0.29000000000000004), 'max_acc': 0.9090909090909091, 'best_cm_acc': [[9, 1], [0, 1]]}, ('clipping', False): {'roc_auc': np.float64(0.8534569643217095), 'best_thresh_fpr': np.float64(0.85), 'fnr_at_1pfpr': np.float64(0.8536585365853658), 'best_cm_fpr': [[120, 1], [70, 12]], 'best_thresh_acc': np.float64(0.55), 'max_acc': 0.8078817733990148, 'best_cm_acc': [[101, 20], [19, 63]]}, ('clipping', True): {'roc_auc': np.float64(0.7500000000000001), 'best_thresh_fpr': np.float64(0.81), 'fnr_at_1pfpr': np.float64(1.0), 'best_cm_fpr': [[6, 0], [2, 0]], 'best_thresh_acc': np.float64(0.46), 'max_acc': 0.75, 'best_cm_acc': [[4, 2], [0, 2]]}, ('time_stretch', False): {'roc_auc': np.float64(0.8616865453023645), 'best_thresh_fpr': np.float64(0.8400000000000001), 'fnr_at_1pfpr': np.float64(0.8024691358024691), 'best_cm_fpr': [[117, 1], [65, 16]], 'best_thresh_acc': np.float64(0.55), 'max_acc': 0.81407035175879 ...

# %%
print(type(results))
# Out:
# <class 'list'>

# %%
print(results[0])
# Out:
# {'global': {'roc_auc': np.float64(0.9723472065991752), 'best_thresh_fpr': np.float64(0.97), 'fnr_at_1pfpr': np.float64(0.7619047619047619), 'best_cm_fpr': [[126, 1], [64, 20]], 'best_thresh_acc': np.float64(0.5800000000000001), 'max_acc': 0.957345971563981, 'best_cm_acc': [[122, 5], [4, 80]]}, 'stratified': {('reverberation', False): {'roc_auc': np.float64(0.9725561110520158), 'best_thresh_fpr': np.float64(0.97), 'fnr_at_1pfpr': np.float64(0.7468354430379747), 'best_cm_fpr': [[118, 1], [59, 20]], 'best_thresh_acc': np.float64(0.5800000000000001), 'max_acc': 0.9595959595959596, 'best_cm_acc': [[114, 5], [3, 76]]}, ('reverberation', True): {'roc_auc': np.float64(0.975), 'best_thresh_fpr': np.float64(0.28), 'fnr_at_1pfpr': np.float64(0.2), 'best_cm_fpr': [[8, 0], [1, 4]], 'best_thresh_acc': np.float64(0.11), 'max_acc': 0.9230769230769231, 'best_cm_acc': [[7, 1], [0, 5]]}, ('room_impulse', False): {'roc_auc': np.float64(0.9716220252912477), 'best_thresh_fpr': np.float64(0.97), 'fnr_at_1pfpr': np.float64(0.7590361445783133), 'best_cm_fpr': [[120, 1], [63, 20]], 'best_thresh_acc': np.float64(0.5800000000000001), 'max_acc': 0.9558823529411765, 'best_cm_acc': [[116, 5], [4, 79]]}, ('room_impulse', True): {'roc_auc': np.float64(1.0), 'best_thresh_fpr': np.float64(0.13), 'fnr_at_1pfpr': np.float64(0.0), 'best_cm_fpr': [[6, 0], [0, 1]], 'best_thresh_acc': np.float64(0.13), 'max_acc': 1.0, 'best_cm_acc': [[6, 0], [0, 1]]}, ('doppler', False): {'roc_auc': np.float64(0.9728116003838362), 'best_thresh_fpr': np.float64(0.97), 'fnr_at_1pfpr': np.float64(0.7590361445783133), 'best_cm_fpr': [[112, 1], [63, 20]], 'best_thresh_acc': np.float64(0.5800000000000001), 'max_acc': 0.9642857142857143, 'best_cm_acc': [[109, 4], [3, 80]]}, ('doppler', True): {'roc_auc': np.float64(0.7142857142857143), 'best_thresh_fpr': np.float64(0.67), 'fnr_at_1pfpr': np.float64(1.0), 'best_cm_fpr': [[14, 0], [1, 0]], 'best_thresh_acc': np.float64(0.67), 'max_acc': 0.9333333333333333, 'best_cm_acc': [[14, 0], [1, 0]]}, ('interference', False): {'roc_auc': np.float64(0.9746700723712217), 'best_thresh_fpr': np.float64(0.97), 'fnr_at_1pfpr': np.float64(0.7530864197530864), 'best_cm_fpr': [[115, 1], [61, 20]], 'best_thresh_acc': np.float64(0.56), 'max_acc': 0.9644670050761421, 'best_cm_acc': [[112, 4], [3, 78]]}, ('interference', True): {'roc_auc': np.float64(0.7575757575757576), 'best_thresh_fpr': np.float64(0.64), 'fnr_at_1pfpr': np.float64(0.6666666666666666), 'best_cm_fpr': [[11, 0], [2, 1]], 'best_thresh_acc': np.float64(0.5800000000000001), 'max_acc': 0.8571428571428571, 'best_cm_acc': [[10, 1], [1, 2]]}, ('compression_artifacts', False): {'roc_auc': np.float64(0.9732262382864793), 'best_thresh_fpr': np.float64(0.97), 'fnr_at_1pfpr': np.float64(0.7590361445783133), 'best_cm_fpr': [[116, 1], [63, 20]], 'best_thresh_acc': np.float64(0.56), 'max_acc': 0.96, 'best_cm_acc': [[113, 4], [4, 79]]}, ('compression_artifacts', True): {'roc_auc': np.float64(1.0), 'best_thresh_fpr': np.float64(0.67), 'fnr_at_1pfpr': np.float64(0.0), 'best_cm_fpr': [[10, 0], [0, 1]], 'best_thresh_acc': np.float64(0.67), 'max_acc': 1.0, 'best_cm_acc': [[10, 0], [0, 1]]}, ('clipping', False): {'roc_auc': np.float64(0.978330981656924), 'best_thresh_fpr': np.float64(0.81), 'fnr_at_1pfpr': np.float64(0.15853658536585366), 'best_cm_fpr': [[120, 1], [13, 69]], 'best_thresh_acc': np.float64(0.5800000000000001), 'max_acc': 0.9655172413793104, 'best_cm_acc': [[118, 3], [4, 78]]}, ('clipping', True): {'roc_auc': np.float64(0.9166666666666667), 'best_thresh_fpr': np.float64(0.97), 'fnr_at_1pfpr': np.float64(0.5), 'best_cm_fpr': [[6, 0], [1, 1]], 'best_thresh_acc': np.float64(0.64), 'max_acc': 0.875, 'best_cm_acc': [[5, 1], [0, 2]]}, ('time_stretch', False): {'roc_auc': np.float64(0.9774011299435028), 'best_thresh_fpr': np.float64(0.81), 'fnr_at_1pfpr': np.float64(0.14814814814814814), 'best_cm_fpr': [[117, 1], [12, 69]], 'best_thresh_acc': np.float64(0.5800000000000001), 'max_acc': 0.9597989949748744, 'best_cm_ ...

# %%
print(results[1])
# Out:
# {'global': {'roc_auc': np.float64(0.9715035620547432), 'best_thresh_fpr': np.float64(0.9), 'fnr_at_1pfpr': np.float64(0.34523809523809523), 'best_cm_fpr': [[126, 1], [29, 55]], 'best_thresh_acc': np.float64(0.51), 'max_acc': 0.9146919431279621, 'best_cm_acc': [[117, 10], [8, 76]]}, 'stratified': {('reverberation', False): {'roc_auc': np.float64(0.9818836625559315), 'best_thresh_fpr': np.float64(0.9), 'fnr_at_1pfpr': np.float64(0.3116883116883117), 'best_cm_fpr': [[118, 1], [24, 53]], 'best_thresh_acc': np.float64(0.72), 'max_acc': 0.9285714285714286, 'best_cm_acc': [[115, 4], [10, 67]]}, ('reverberation', True): {'roc_auc': np.float64(0.8035714285714285), 'best_thresh_fpr': np.float64(0.81), 'fnr_at_1pfpr': np.float64(0.42857142857142855), 'best_cm_fpr': [[8, 0], [3, 4]], 'best_thresh_acc': np.float64(0.42000000000000004), 'max_acc': 0.8, 'best_cm_acc': [[7, 1], [2, 5]]}, ('room_impulse', False): {'roc_auc': np.float64(0.9738000000000001), 'best_thresh_fpr': np.float64(0.9), 'fnr_at_1pfpr': np.float64(0.325), 'best_cm_fpr': [[124, 1], [26, 54]], 'best_thresh_acc': np.float64(0.51), 'max_acc': 0.926829268292683, 'best_cm_acc': [[115, 10], [5, 75]]}, ('room_impulse', True): {'roc_auc': np.float64(1.0), 'best_thresh_fpr': np.float64(0.13), 'fnr_at_1pfpr': np.float64(0.0), 'best_cm_fpr': [[2, 0], [0, 4]], 'best_thresh_acc': np.float64(0.13), 'max_acc': 1.0, 'best_cm_acc': [[2, 0], [0, 4]]}, ('doppler', False): {'roc_auc': np.float64(0.9752083333333332), 'best_thresh_fpr': np.float64(0.9), 'fnr_at_1pfpr': np.float64(0.325), 'best_cm_fpr': [[119, 1], [26, 54]], 'best_thresh_acc': np.float64(0.72), 'max_acc': 0.93, 'best_cm_acc': [[117, 3], [11, 69]]}, ('doppler', True): {'roc_auc': np.float64(0.7857142857142857), 'best_thresh_fpr': np.float64(0.86), 'fnr_at_1pfpr': np.float64(0.75), 'best_cm_fpr': [[7, 0], [3, 1]], 'best_thresh_acc': np.float64(0.12), 'max_acc': 0.8181818181818182, 'best_cm_acc': [[5, 2], [0, 4]]}, ('interference', False): {'roc_auc': np.float64(0.9788162657015117), 'best_thresh_fpr': np.float64(0.9), 'fnr_at_1pfpr': np.float64(0.2987012987012987), 'best_cm_fpr': [[121, 1], [23, 54]], 'best_thresh_acc': np.float64(0.44), 'max_acc': 0.9346733668341709, 'best_cm_acc': [[111, 11], [2, 75]]}, ('interference', True): {'roc_auc': np.float64(0.6857142857142857), 'best_thresh_fpr': np.float64(0.86), 'fnr_at_1pfpr': np.float64(0.8571428571428571), 'best_cm_fpr': [[5, 0], [6, 1]], 'best_thresh_acc': np.float64(0.16), 'max_acc': 0.75, 'best_cm_acc': [[2, 3], [0, 7]]}, ('compression_artifacts', False): {'roc_auc': np.float64(0.974025974025974), 'best_thresh_fpr': np.float64(0.9), 'fnr_at_1pfpr': np.float64(0.2987012987012987), 'best_cm_fpr': [[120, 1], [23, 54]], 'best_thresh_acc': np.float64(0.81), 'max_acc': 0.9343434343434344, 'best_cm_acc': [[117, 4], [9, 68]]}, ('compression_artifacts', True): {'roc_auc': np.float64(1.0), 'best_thresh_fpr': np.float64(0.44), 'fnr_at_1pfpr': np.float64(0.0), 'best_cm_fpr': [[6, 0], [0, 7]], 'best_thresh_acc': np.float64(0.44), 'max_acc': 1.0, 'best_cm_acc': [[6, 0], [0, 7]]}, ('clipping', False): {'roc_auc': np.float64(0.97215821812596), 'best_thresh_fpr': np.float64(0.9), 'fnr_at_1pfpr': np.float64(0.34523809523809523), 'best_cm_fpr': [[123, 1], [29, 55]], 'best_thresh_acc': np.float64(0.44), 'max_acc': 0.9134615384615384, 'best_cm_acc': [[112, 12], [6, 78]]}, ('time_stretch', False): {'roc_auc': np.float64(0.9759453781512606), 'best_thresh_fpr': np.float64(0.9), 'fnr_at_1pfpr': np.float64(0.3125), 'best_cm_fpr': [[118, 1], [25, 55]], 'best_thresh_acc': np.float64(0.72), 'max_acc': 0.9346733668341709, 'best_cm_acc': [[116, 3], [10, 70]]}, ('time_stretch', True): {'roc_auc': np.float64(0.8125), 'best_thresh_fpr': np.float64(0.85), 'fnr_at_1pfpr': np.float64(0.75), 'best_cm_fpr': [[8, 0], [3, 1]], 'best_thresh_acc': np.float64(0.18000000000000002), 'max_acc': 0.8333333333333334, 'best_cm_acc': [[6, 2], [0, 4]]}, ('pitch_loudness', False): {'roc_auc': np.float64(0.9733551957368313), 'best_thr ...

# %%
import numpy as np
import matplotlib.pyplot as plt


def sum_conf_matrices(results, key='global', cm_key='best_cm_acc'):
    summed_cm = np.zeros((2, 2), dtype=int)
    for fold in results:
        cm = np.array(fold[key][cm_key])
        summed_cm += cm
    return summed_cm

def sum_stratified_conf_matrices(results, strat_key, cm_key='best_cm_acc'):
    summed_cm = np.zeros((2, 2), dtype=int)
    for fold in results:
        if strat_key in fold['stratified']:
            cm = np.array(fold['stratified'][strat_key][cm_key])
            summed_cm += cm
    return summed_cm

def plot_conf_matrix(cm, title):
    fig, ax = plt.subplots()
    cax = ax.matshow(cm, cmap='Blues')
    for (i, j), val in np.ndenumerate(cm):
        ax.text(j, i, f'{val}', ha='center', va='center', color='black', fontsize=14)
    ax.set_xlabel('Predicted', fontsize=12)
    ax.set_ylabel('Actual', fontsize=12)
    ax.set_xticks([0, 1])
    ax.set_yticks([0, 1])
    ax.set_title(title, fontsize=14)
    fig.colorbar(cax)
    plt.show()

# %%
# GLOBAL: sum & display
global_cm_acc = sum_conf_matrices(results, key='global', cm_key='best_cm_acc')
global_cm_fpr = sum_conf_matrices(results, key='global', cm_key='best_cm_fpr')

plot_conf_matrix(global_cm_acc, 'Global Confusion Matrix (Best Accuracy Threshold)')
plot_conf_matrix(global_cm_fpr, 'Global Confusion Matrix (Best FPR Threshold)')

# %%
# STRATIFIED
strats = [
        "reverberation",
        "room_impulse",
        "doppler",
        "interference",
        "compression_artifacts",
        "clipping",
        "time_stretch",
        "pitch_loudness",
        "frequency_filter",
        "white_noise",
        "ambient_noise",
    ]

for condition in [True, False]:
    for strat in strats:
        strat_key = (strat, condition)
        strat_cm_acc = sum_stratified_conf_matrices(results, strat_key, cm_key='best_cm_acc')
        strat_cm_fpr = sum_stratified_conf_matrices(results, strat_key, cm_key='best_cm_fpr')

        plot_conf_matrix(strat_cm_acc, f'{strat}={condition} (Best Accuracy Threshold)')
        plot_conf_matrix(strat_cm_fpr, f'{strat}={condition} (Best FPR Threshold)')

# %%
python evaluation/embeddings/embedding_eval.py \
  --embeddings embeddings/audio/hubert/hubert_embeddings.npy \
  --labels labels/audio/hubert/hubert_labels.pkl \
  --metadata data/exploratory-datasets/audio_dataset_with_perturbations.pkl \
  --stratify_mode audio \
  --output hubert_stratified_results.pkl
